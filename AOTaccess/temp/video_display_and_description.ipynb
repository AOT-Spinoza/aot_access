# %%
import os
import sys
from IPython.display import Video
from AOTaccess.stimulus_info_access import StimuliInfoAccess

access = StimuliInfoAccess()

# %%
# %matplotlib inline
def display_video(video_num,derection="fw"):
    video_path = access.get_video_path(video_num,derection)
    Video(video_path,embed=True)

def display_video_and_descrptipn(video_num,derection="fw"):
    video_path = access.get_video_path(video_num,derection)
    print(access.read_llama_description(video_num, derection))
    Video(video_path,embed=True)

# %%
id = 197
print(access._temp_read_llama_description(id))
Video(access.get_video_path(id),embed=True,)
# Out:
# a man wearing a welding helmet working on the engine of a car. He is using a welding torch to make repairs or modifications to the car's engine. The bright blue light emitted by the torch indicates that it is producing a high temperature and is capable of melting metal. The man's protective gear suggests that this is a potentially dangerous task and he is taking the necessary precautions to ensure his safety. Overall, this video showcases the skill and expertise required to work on the engine of a car and highlights the importance of safety when performing such tasks.
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
