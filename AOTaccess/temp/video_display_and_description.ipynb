# %%
import os
import sys
from IPython.display import Video
from AOTaccess.stimulus_info_access import StimuliInfoAccess
from pprint import pprint


access = StimuliInfoAccess()

# %%
# %matplotlib inline
def display_video(video_num,derection="fw"):
    video_path = access.get_video_path(video_num,derection)
    Video(video_path,embed=True)

def display_video_and_descrptipn(video_num,derection="fw"):
    video_path = access.get_video_path(video_num,derection)
    print(access.read_llama_description(video_num, derection))
    Video(video_path,embed=True)

# %%
id = 100
print("2.0version:")
pprint(access._temp_read_llama_description(id))
print("2.1version:")
pprint(access._temp_read_llama_description_v2(id))
Video(access.get_video_path(id),embed=True,)
# Out:
# 2.0version:
# ('a person typing on a laptop keyboard in the dark. The video starts with a '
#  "shot of the person's hands on the keyboard, and we can see the keys being "
#  'pressed as they type. The screen of the laptop is visible, and we can see '
#  'that the person is typing commands into the computer. The video is shot in a '
#  'dark room, with only a small amount of light coming from the laptop screen. '
#  "The person's hands are the only thing visible in the shot, and we can see "
#  'their fingers moving quickly over the keys. The sound of the keys being '
#  'pressed can be heard clearly, and we can hear the person breathing as they '
#  'work. Overall, the video gives the impression of someone working on a '
#  'computer in a quiet, dark environment.')
# 2.1version:
# ("In this video, we see a person's hand typing on a laptop keyboard in the "
#  'dark. The screen of the laptop is illuminated with green light, and the '
#  "person's fingers move quickly across the keys. We can hear the sound of the "
#  'keys clicking as they type. The scene appears to be taking place in a dimly '
#  'lit room or office space. The atmosphere is quiet and focused, with no other '
#  'sounds or distractions present. It seems that the person is deeply engrossed '
#  'in their work, perhaps writing a report or coding a program. Overall, the '
#  'video captures a moment of intense concentration and productivity.\n')
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
