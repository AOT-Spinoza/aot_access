# %%
import os
import sys
from IPython.display import Video
from AOTaccess.stimulus_info_access import StimuliInfoAccess

access = StimuliInfoAccess()

# %%
# %matplotlib inline
def display_video(video_num,derection="fw"):
    video_path = access.get_video_path(video_num,derection)
    Video(video_path,embed=True)

def display_video_and_descrptipn(video_num,derection="fw"):
    video_path = access.get_video_path(video_num,derection)
    print(access._temp_read_llama_description(video_num, derection))
    Video(video_path,embed=True)

# %%
id = 137
print(access._temp_read_llama_description(id))
Video(access.get_video_path(id),embed=True,)
# Out:
# a machine that is printing a pink object. The video starts with a close-up shot of the machine, and we can see the object being printed layer by layer. As the video progresses, we can see the machine moving and adjusting itself to ensure that the object is printed accurately. The machine makes a beeping sound as it completes each layer of the object. We can also see the object being printed taking a definite shape, and we can see the intricate details being formed. The video ends with a shot of the completed object, which looks like a small toy or figurine. Overall, the video showcases the process of 3D printing and the level of detail and accuracy that can be achieved using this technology.
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
