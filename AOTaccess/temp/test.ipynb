# %%
import AOTaccess
import sys
import os
from AOTaccess.glmsingle_access import GLMSingleAccess
from AOTaccess.expdesign_access import ExpDesignAccess
from AOTaccess.explog_access import ExpLogAccess

# %%
#test explog access
explogaccess = ExpLogAccess()
funcdir = explogaccess.get_func_dir(1,1)
print(funcdir)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 #test explog access
#       2 explogaccess = ExpLogAccess()
# ----> 3 funcdir = explogaccess.get_func_dir(1,1)
#       4 print(funcdir)
#
# File ~/AOT_code_repos/aot_access/AOTaccess/explog_access.py:21, in ExpLogAccess.get_func_dir(self, sub, ses)
#      19 layout = BIDSLayout(self.bids_dir)
#      20 func_dir = layout.get(subject=sub, session=ses, datatype="func")
# ---> 21 return func_dir[0].path
#
# IndexError: list index out of range
