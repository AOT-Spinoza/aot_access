# %%
import AOTaccess
import sys
import os
from AOTaccess.glmsingle_access import GLMSingleAccess
from AOTaccess.expdesign_access import ExpDesignAccess

# %%
#test glmsingle acess
GLMsub1ses1 = GLMSingleAccess(1,1)
#betassub1ses1 = GLMsub1ses1.read_betas()

#test expdesign access
expdesignsub1ses1 = ExpDesignAccess(1,1)
settingssub1ses1 = expdesignsub1ses1.read_expdesign_file(run=1)

print(settingssub1ses1)

alltrailswithoutblanks = expdesignsub1ses1.append_all_trails_without_blanks()
# Out:
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_01.yml
# ...
