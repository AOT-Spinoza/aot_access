# %%
from AOTaccess.glmsingle_access import GLMSingleAccess

# %%
glmaccess = GLMSingleAccess()
testbeta = glmaccess.read_video_betas(sub=3,video_num=1,average=True)
print("Test beta values for video 1:")
print(testbeta.shape)
# Out:
# Test beta values for video 1:
# (84, 95, 106)
