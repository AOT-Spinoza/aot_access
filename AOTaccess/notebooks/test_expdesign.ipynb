# %% [markdown]
# # Test ExpDesignAccess Methods
#
# This notebook tests all methods in the ExpDesignAccess class.

# %%
import sys
sys.path.append('..')
from expdesign_access import ExpDesignAccess

# %%
# Initialize the ExpDesignAccess instance
exp_design = ExpDesignAccess()

# Test parameters
sub = 1  # subject 1
ses = 1  # session 1
run = 1  # run 1

# %% [markdown]
# ## Test read_expdesign_file

# %%
# Test reading expdesign file for a specific run
expdesign = exp_design.read_expdesign_file(sub, ses, run)
print("\nExpdesign for single run:")
print(expdesign)
# Out:
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_01.yml
#
# Expdesign for single run:
# ...

# %% [markdown]
# ## Test read_session_expdesign

# %%
# Test reading expdesign for all runs in a session
session_movies = exp_design.read_session_expdesign(sub, ses)
print("\nSession movies:")
print(session_movies)
# Out:
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_01.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_02.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_03.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_04.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_05.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_06.yml
# ...

# %% [markdown]
# ## Test append_all_trails_without_blanks

# %%
# Test getting all trials without blanks
trials_no_blanks = exp_design.append_all_trails_without_blanks(sub, ses)
print("\nTrials without blanks:")
print(trials_no_blanks)
# Out:
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_01.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_02.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_03.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_04.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_05.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_06.yml
# ...

# %% [markdown]
# ## Test get_session_video_indexes

# %%
# Test getting video indexes for a session
video_indexes = exp_design.get_session_video_indexes(sub, ses)
print("\nVideo indexes:")
print(video_indexes)
# Out:
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_01.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_02.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_03.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_04.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_05.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_06.yml
# ...

# %% [markdown]
# ## Test get_session_uniqe_video_indexes

# %%
# Test getting unique video indexes for a session
unique_indexes = exp_design.get_session_uniqe_video_indexes(sub, ses)
print("\nUnique video indexes:")
print(unique_indexes)
# Out:
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_01.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_02.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_03.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_04.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_05.yml
# Loaded expdesign from /tank/zhangs/AOT_code_repos/arrow_of_time_experiment/aot/data/experiment/settings/main/experiment_settings_sub_01_ses_01_run_06.yml
# ...
