# %% [markdown]
# # Test PreprocedAccess Class
#
# This notebook tests all functions in the PreprocedAccess class.

# %%
import sys
import numpy as np
from pathlib import Path
from pprint import pprint
sys.path.append('..')
from preproced_access import PreprocedAccess

# %%
# Initialize the PreprocedAccess instance
preproced_access = PreprocedAccess()

# Test parameters
test_sub = 1  # test subject
test_ses = 1  # test session
test_run = 1  # test run
test_task = "AOT"  # test task
test_resolution = "1.7mm"  # test resolution

# %% [markdown]
# ## Test Functional Image Reading

# %%
# Test read_func
print("Loading functional image:")
func_img = preproced_access.read_func(test_sub, test_ses, test_run, test_task, test_resolution)
print(f"Shape of functional image: {func_img.shape}")
# Out:
# Loading functional image:
# Shape of functional image: (81, 95, 101, 370)
